# %%
import pandas as pd 
import numpy as np
from pandas import DataFrame,Series

# %%
path_name="./titanic-data.csv"
titantic_data = pd.read_csv(path_name)
df_titantic=DataFrame(titantic_data)

# %%
#筛选出生还和未生还的数据
survived=df_titantic[df_titantic['Survived']==1]
unsurvived=df_titantic[df_titantic['Survived']==0]

# %%
#查看每一列的数目，确定数据是否准确
print 'Survived number of index:'
print survived.count()
print 'Unsurvived number of index'
print unsurvived.count()
# Out:
# Survived number of index:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# dtype: int64
# Unsurvived number of index
# PassengerId    549
# Survived       549
# Pclass         549
# Name           549
# Sex            549
# Age            424
# SibSp          549
# Parch          549
# Ticket         549
# Fare           549
# Cabin           68
# Embarked       549
# dtype: int64

# %%
#通过以上代码显示index数量，发现age和cabin数量与乘客数不匹配，进一步清洗age异常数据
survived=survived[survived['Age']>0]
unsurvived=unsurvived[unsurvived['Age']>0]
#筛选出生还者pclass,sex，ages数据
p_class_survived=survived['Pclass']
sex_survived=survived['Sex']
age_survived=survived['Age']
#筛选出遇难者pclass,sex，ages数据
p_class_unsurvived=unsurvived['Pclass']
sex_unsurvived=unsurvived['Sex']
age_unsurvived=unsurvived['Age']

# %%
#绘制图形  按照票等级排序的直方图
% pylab inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.xlabel('P_Class')
plt.ylabel('Number of P_Class')
plt.title('P_Class of survived')
p_class_survived.value_counts(sort=False).plot(kind='bar')
sns.set(color_codes=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xlabel('SEX')
plt.ylabel('Number of SEX')
plt.title('SEX of survived')
sex_survived.value_counts(sort=False).plot(kind='bar')
plt.show()
sns.set(color_codes=True)

# %%
plt.xlabel('Age')
plt.ylabel('Number of Age')
plt.title('Age of survived')
plt.hist(age_survived, bins=10)
plt.show()
sns.set(color_codes=True)

# %%
plt.xlabel('P_Class')
plt.ylabel('Number of P_Class')
plt.title('P_Class of unsurvived')
p_class_unsurvived.value_counts(sort=False).plot(kind='bar')
sns.set(color_codes=True)

# %%
plt.xlabel('SEX')
plt.ylabel('Number of SEX')
plt.title('SEX of unsurvived')
sex_unsurvived.value_counts(sort=False).plot(kind='bar')
plt.show()
sns.set(color_codes=True)

# %%
plt.xlabel('Age')
plt.ylabel('Number of Age')
plt.title('Age of unsurvived')
plt.hist(age_unsurvived, bins=10)
plt.show()
sns.set(color_codes=True)

# %%
#根据图表，发现age图表数据异常，20-30左右生还和遇难的比例都较高，猜测原因可能是由于这个年龄段乘船人数较多
age_all=df_titantic[df_titantic['Age']>0]
plt.xlabel('Age')
plt.ylabel('Number of Age')
plt.title('Age of all passenger')
plt.hist(age_unsurvived, bins=10)
plt.show()
sns.set(color_codes=True)
#根据图表，证实了猜测

# %%
#将age进行分组
def div_age(group_data):
    if group_data<10:
        group_data='0-10'
    if group_data<20:
        group_data='10-20'
    if group_data<30:
        group_data='20-30'
    if group_data<40:
        group_data='30-40'
    if group_data<50:
        group_data='40-50'
    if group_data<60:
        group_data='50-60'
    if group_data<70:
        group_data='60-70'
    if group_data<=80:
        group_data='70-80'
    return group_data

# %%
 #将所有人年龄分组
div_sur_age=survived['Age'].apply(div_age)
div_unsur_age=unsurvived['Age'].apply(div_age)
div_all_age=age_all['Age'].apply(div_age)

# %%
#计算出各个组存活的概率
rate_of_survived=div_sur_age.value_counts(sort=False)/div_all_age.value_counts(sort=False)
rate_of_survived=DataFrame(rate_of_survived)
print rate_of_survived
# Out:
#             Age
# 0-10   0.612903
# 10-20  0.401961
# 20-30  0.350000
# 30-40  0.437126
# 40-50  0.382022
# 50-60  0.416667
# 60-70  0.315789
# 70-80  0.142857

# %%
#绘制概率图
rate_of_survived.plot(kind='bar')
